# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
import matplotlib.pyplot as plt 
import numpy as np

# %%
hours_studied = np.array([1, 2, 2.5, 3, 4, 4.5, 5, 6, 6.5, 7, 8, 9]).reshape(-1, 1)
exam_scores   = np.array([35, 45, 48, 55, 60, 63, 68, 75, 78, 82, 88, 95])

# %%
x_train,x_test,y_train,y_test=train_test_split(hours_studied, exam_scores, test_size=0.2, random_state=42)
